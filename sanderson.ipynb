# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
import time

# %%
url = 'https://app.thestorygraph.com/browse?search_term=brandon%20sanderson'
headers = {"User-Agent": "Mozilla/5.0"}  
response = requests.get(url, headers=headers)

print(response.status_code)
# Out:
# 403

# %%
soup = BeautifulSoup(response.text, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
driver = webdriver.Chrome()
driver.get(url)

time.sleep(30)  # allow page to load

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

books = soup.find_all("div", class_="book-title-author-and-series")

for book in books:
    title = book.find("h3").text.strip()
    author = book.find("p").text.strip()
    print(title, "-", author)

driver.quit()
# Out:
# The Final Empire
#
# Brandon Sanderson - Mistborn #1
# The Final Empire
#
# Brandon Sanderson - Mistborn #1
# The Way of Kings
#
# Brandon Sanderson - The Stormlight Archive #1
# The Way of Kings
#
# Brandon Sanderson - The Stormlight Archive #1
# The Well of Ascension
#
# Brandon Sanderson - Mistborn #2
# The Well of Ascension
#
# Brandon Sanderson - Mistborn #2
# The Hero of Ages
#
# Brandon Sanderson - Mistborn #3
# The Hero of Ages
#
# Brandon Sanderson - Mistborn #3
# Words of Radiance
#
# Brandon Sanderson - The Stormlight Archive #2
# Words of Radiance
#
# Brandon Sanderson - The Stormlight Archive #2
# Tress of the Emerald Sea
#
# Brandon Sanderson - Hoid’s Travails #1
# Tress of the Emerald Sea
#
# Brandon Sanderson - Hoid’s Travails #1
# Elantris
#
# Brandon Sanderson - Elantris #1
# Elantris
#
# Brandon Sanderson - Elantris #1
# Oathbringer
#
# Brandon Sanderson - The Stormlight Archive #3
# Oathbringer
#
# Brandon Sanderson - The Stormlight Archive #3
# Rhythm of War
#
# ...

# %%
len(books)
# Out:
# 40

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://app.thestorygraph.com/browse?search_term=brandon%20sanderson")

time.sleep(3)

# Scroll multiple times
for i in range(10):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

html = driver.page_source

from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "html.parser")

books = soup.find_all("div", class_="book-title-author-and-series")

for book in books:
    print(book.text.strip())
# Out:
# Mistborn #1
# The Final Empire
#
# Brandon Sanderson
# Mistborn #1
# The Final Empire
#
# Brandon Sanderson
# The Stormlight Archive #1
# The Way of Kings
#
# Brandon Sanderson
# The Stormlight Archive #1
# The Way of Kings
#
# Brandon Sanderson
# Mistborn #2
# The Well of Ascension
#
# Brandon Sanderson
# Mistborn #2
# The Well of Ascension
#
# Brandon Sanderson
# Mistborn #3
# The Hero of Ages
#
# Brandon Sanderson
# Mistborn #3
# The Hero of Ages
#
# Brandon Sanderson
# The Stormlight Archive #2
# Words of Radiance
#
# Brandon Sanderson
# The Stormlight Archive #2
# Words of Radiance
#
# Brandon Sanderson
# Hoid’s Travails #1
# Tress of the Emerald Sea
#
# Brandon Sanderson
# Hoid’s Travails #1
# Tress of the Emerald Sea
#
# Brandon Sanderson
# Elantris #1
# Elantris
#
# Brandon Sanderson
# Elantris #1
# Elantris
#
# Brandon Sanderson
# The Stormlight Archive #3
# Oathbringer
#
# Brandon Sanderson
# The Stormlight Archive #3
# Oathbringer
#
# Brandon Sanderson
# ...

# %%
len(books)
# Out:
# 220
